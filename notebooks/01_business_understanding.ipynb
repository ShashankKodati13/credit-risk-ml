# %% [markdown]
# Business Problem
#
# A digital lending platform wants to predict whether a customer will default next month.
#
# The objective is to minimize financial loss due to defaults while maintaining customer acquisition.

# %%
import pandas as pd

# Load dataset
file_path = "../data/raw/default_of_credit_card_clients.xls"

df = pd.read_excel(file_path, header=1)

# Preview data
df.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
df.shape
# Out:
# (30000, 25)

# %%
df.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  int64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default payment next month    0
# dtype: int64

# %%
df["default payment next month"].value_counts()
# Out:
# default payment next month
# 0    23364
# 1     6636
# Name: count, dtype: int64

# %%
df["default payment next month"].value_counts(normalize=True)
# Out:
# default payment next month
# 0    0.7788
# 1    0.2212
# Name: proportion, dtype: float64

# %%
df = df.drop(columns=["ID"])
df = df.rename(columns={
    "default payment next month": "default"
})
df.columns
# Out:
# Index(['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0', 'PAY_2',
#        'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6', 'default'],
#       dtype='str')

# %%
df = df.rename(columns={"PAY_0": "PAY_1"})

# %%
df["SEX"].unique()
# Out:
# array([2, 1])

# %%
df["EDUCATION"].unique()
# Out:
# array([2, 1, 3, 5, 4, 6, 0])

# %%
df["MARRIAGE"].unique()
# Out:
# array([1, 2, 3, 0])

# %%
df["EDUCATION"] = df["EDUCATION"].replace([0,5,6],4)
df["EDUCATION"].unique()
# Out:
# array([2, 1, 3, 4])

# %%
df["MARRIAGE"] = df["MARRIAGE"].replace(0,3)
df["MARRIAGE"].unique()
# Out:
# array([1, 2, 3])

# %%
df.describe()
# Out:
#             LIMIT_BAL           SEX     EDUCATION      MARRIAGE           AGE  \
# count    30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean    167484.322667      1.603733      1.842267      1.557267     35.485500
# std     129747.661567      0.489129      0.744494      0.521405      9.217904
# min      10000.000000      1.000000      1.000000      1.000000     21.000000
# 25%      50000.000000      1.000000      1.000000      1.000000     28.000000
# 50%     140000.000000      2.000000      2.000000      2.000000     34.000000
# 75%     240000.000000      2.000000      2.000000      2.000000     41.000000
# max    1000000.000000      2.000000      4.000000      3.000000     79.000000
#
#               PAY_1         PAY_2         PAY_3         PAY_4         PAY_5  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      -0.016700     -0.133767     -0.166200     -0.220667     -0.266200
# ...

# %% [markdown]
# Separate features and target

# %%
x =  df.drop(columns = ["default"])
y = df["default"]
x.shape, y.shape
# Out:
# ((30000, 23), (30000,))

# %% [markdown]
# Train-Test Split

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, 
                                    test_size = 0.2, random_state = 42, stratify = y)
x_train.shape, x_test.shape
# Out:
# ((24000, 23), (6000, 23))

# %% [markdown]
# feature scaling

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %% [markdown]
# Train first Model - LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(max_iter=1000)
model.fit(x_train_scaled, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %% [markdown]
# Evaluate Model

# %%
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score

y_pred = model.predict(x_test_scaled)

print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
print("\nROC-AUC:", roc_auc_score(y_test, model.predict_proba(x_test_scaled)[:,1]))
# Out:
# Confusion Matrix:
#  [[4529  144]
#  [1006  321]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.82      0.97      0.89      4673
#            1       0.69      0.24      0.36      1327
#
#     accuracy                           0.81      6000
#    macro avg       0.75      0.61      0.62      6000
# weighted avg       0.79      0.81      0.77      6000
#
#
# ROC-AUC: 0.707924808472601

# %% [markdown]
# From the Classification Report we can observe that the recall for default class (1) is 0.24 which is very low.
# Meaning, the current model is missing ~76% of defaulters which leads to financial loss.
#
# Hence we Improve Recall by Changing Threshold.

# %%
import numpy as np

y_prob = model.predict_proba(x_test_scaled)[:,1]

threshold = 0.3
y_pred_new = (y_prob >= threshold).astype(int)

from sklearn.metrics import classification_report, confusion_matrix

print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_new))
print("\nClassification Report:\n", classification_report(y_test, y_pred_new))
# Out:
# Confusion Matrix:
#  [[4179  494]
#  [ 717  610]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.89      0.87      4673
#            1       0.55      0.46      0.50      1327
#
#     accuracy                           0.80      6000
#    macro avg       0.70      0.68      0.69      6000
# weighted avg       0.79      0.80      0.79      6000

# %% [markdown]
# Finding Best Threshold Systematically:
#
# Instead of guessing 0.3, we compute optimal threshold.

# %%
from sklearn.metrics import roc_curve

fpr, tpr, thresholds = roc_curve(y_test, y_prob)

# Youden's J statistic
J = tpr - fpr
ix = np.argmax(J)
best_threshold = thresholds[ix]
print("Best Threshold:", best_threshold)
# Out:
# Best Threshold: 0.25323890951932804

# %%
import numpy as np

y_prob = model.predict_proba(x_test_scaled)[:,1]

threshold = 0.25323890951932804
y_pred_new = (y_prob >= threshold).astype(int)

from sklearn.metrics import classification_report, confusion_matrix

print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_new))
print("\nClassification Report:\n", classification_report(y_test, y_pred_new))
# Out:
# Confusion Matrix:
#  [[3813  860]
#  [ 600  727]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.86      0.82      0.84      4673
#            1       0.46      0.55      0.50      1327
#
#     accuracy                           0.76      6000
#    macro avg       0.66      0.68      0.67      6000
# weighted avg       0.77      0.76      0.76      6000

# %% [markdown]
# Now Let's try with a more advanced model.
#
# Random Forest.
#
# Training Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score

rf = RandomForestClassifier(
    n_estimators=200,
    max_depth=None,
    random_state=42,
    n_jobs=-1
)

rf.fit(x_train, y_train)
rf_prob = rf.predict_proba(x_test)[:,1]
print("Random Forest ROC-AUC:", roc_auc_score(y_test, rf_prob))
# Out:
# Random Forest ROC-AUC: 0.7586845078858153

# %% [markdown]
# Training the XGBoost model

# %%
from xgboost import XGBClassifier

xgb = XGBClassifier(
    n_estimators=300,
    max_depth=4,
    learning_rate=0.05,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42,
    eval_metric="logloss"
)

xgb.fit(x_train, y_train)

xgb_prob = xgb.predict_proba(x_test)[:,1]

print("XGBoost ROC-AUC:", roc_auc_score(y_test, xgb_prob))
# Out:
# XGBoost ROC-AUC: 0.777254445240185

# %% [markdown]
# ROC-Curve Comparision

# %%
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt

models = {
    "Logistic": y_prob,
    "Random Forest": rf_prob,
    "XGBoost": xgb_prob
}

plt.figure(figsize=(8,6))

for name, probs in models.items():
    fpr, tpr, _ = roc_curve(y_test, probs)
    auc = roc_auc_score(y_test, probs)
    plt.plot(fpr, tpr, label=f"{name} (AUC = {auc:.3f})")

plt.plot([0,1],[0,1],'k--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve Comparison")
plt.legend()
plt.show()

# %% [markdown]
# Profit vs Threshold

# %%
import numpy as np
from sklearn.metrics import confusion_matrix

loss_per_default = 7000
profit_per_good = 1000

thresholds = np.linspace(0.01, 0.99, 100)
profits = []

for t in thresholds:
    preds = (xgb_prob >= t).astype(int)
    
    tn, fp, fn, tp = confusion_matrix(y_test, preds).ravel()
    
    profit = (tn * profit_per_good) - (fn * loss_per_default)
    profits.append(profit)

plt.figure(figsize=(8,6))
plt.plot(thresholds, profits)
plt.xlabel("Threshold")
plt.ylabel("Profit")
plt.title("Profit vs Threshold (XGBoost)")
plt.show()

print("Best Profit Threshold:", thresholds[np.argmax(profits)])
# Out:
# Best Profit Threshold: 0.11888888888888888

# %% [markdown]
# Let's Run SHAP now

# %%
import shap

explainer = shap.TreeExplainer(xgb)
shap_values = explainer.shap_values(x_test)

shap.summary_plot(shap_values, x_test)

# %% [markdown]
# Save the Trained Model

# %%
import joblib

joblib.dump(xgb, "../models/xgb_credit_model.pkl")
# Out:
# ['../models/xgb_credit_model.pkl']
